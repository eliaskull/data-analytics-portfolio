# %% [markdown]
# <center><img src="redpopcorn.jpg"></center>

# %% [markdown]
# ¡**Netflix**! Lo que empezó en 1997 como un servicio de alquiler de DVD se ha convertido en una de las mayores compañías de entretenimiento y medios.
#
# Dado el gran número de películas y series disponibles en la plataforma, es una oportunidad perfecta para poner en práctica tus habilidades de análisis exploratorio de datos y adentrarte en la industria del entretenimiento.
#
# Trabajas para una productora especializada en estilos nostálgicos. Quieres investigar las películas estrenadas en la década de 1990. ¡Te sumergirás en los datos de Netflix y harás un análisis exploratorio para entender mejor esa fantástica década del cine!
#
# Se te ha proporcionado el conjunto de datos `netflix_data.csv`, junto con la siguiente tabla que detalla los nombres de las columnas y sus descripciones. ¡Siéntete libre de seguir experimentando después de enviar tu solución!
#
# ## Los datos
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | ID del título |
# | `type` | Tipo de título |
# | `title` | Título |
# | `director` | Director o directora |
# | `cast` | Reparto |
# | `country` | País de origen |
# | `date_added` | Fecha de incorporación a Netflix |
# | `release_year` | Año de estreno en Netflix |
# | `duration` | Duración del título en minutos |
# | `description` | Descripción del título |
# | `genre` | Género del título |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")

# %%
netflix_df.head()
# Out:
#   show_id  ...             genre
# 0      s2  ...            Dramas
# 1      s3  ...     Horror Movies
# 2      s4  ...            Action
# 3      s5  ...            Dramas
# 4      s6  ...  International TV
#
# [5 rows x 11 columns]

# %% [markdown]
# 1.- ¿Cuál fue la duración de película más frecuente en los años 90? Guarda una respuesta aproximada como un entero llamado duration (usa 1990 como el año de inicio de la década).

# %%
noventa=netflix_df.loc[(netflix_df['release_year']>=1990) & (netflix_df['release_year']<=1999) &(netflix_df['type']=='Movie'),['type','duration']]
duration=noventa['duration'].mode()[0]
print(str(duration)+' minutes')
# Out:
# 94 minutes

# %% [markdown]
# 2.- Una película se considera corta si dura menos de 90 minutos. Cuenta el número de películas de acción cortas estrenadas en los años 90 y guarda este entero como short_movie_count.

# %%
noventa=netflix_df.loc[(netflix_df['release_year']>=1990) & (netflix_df['release_year']<=1999)&(netflix_df['type']=='Movie') & (netflix_df['genre']=='Action') & (netflix_df['duration']<90),['type','duration']]
short_movie_count=noventa['duration'].count()
print('número de películas de acción cortas estrenadas en los años 90 : '+str(short_movie_count))
# Out:
# número de películas de acción cortas estrenadas en los años 90 : 7
